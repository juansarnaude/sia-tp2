# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_crossover/crossover_Annular.csv', '../output_Archer/output_crossover/crossover_OnePoint.csv',
           '../output_Archer/output_crossover/crossover_TwoPoints.csv', '../output_Archer/output_crossover/crossover_Uniform.csv']
files_2 = ['../output_Mage/output_crossover/crossover_Annular.csv', '../output_Mage/output_crossover/crossover_OnePoint.csv',
           '../output_Mage/output_crossover/crossover_TwoPoints.csv', '../output_Mage/output_crossover/crossover_Uniform.csv']
files_3 = ['../output_Warden/output_crossover/crossover_Annular.csv', '../output_Warden/output_crossover/crossover_OnePoint.csv',
           '../output_Warden/output_crossover/crossover_TwoPoints.csv', '../output_Warden/output_crossover/crossover_Uniform.csv']
files_4 = ['../output_Warrior/output_crossover/crossover_Annular.csv', '../output_Warrior/output_crossover/crossover_OnePoint.csv',
           '../output_Warrior/output_crossover/crossover_TwoPoints.csv', '../output_Warrior/output_crossover/crossover_Uniform.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ['Annular', 'OnePoint', 'TwoPoint', 'Uniform']

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Crossover Methods')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Crossover Method - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_crossover_generation_count.png')
    plt.savefig(output_path)
    plt.close()
    
    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Crossover Methods')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Crossover Method - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_crossover_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_mutation/mutation_GeneMutation.csv', '../output_Archer/output_mutation/mutation_MultiGeneMutation.csv']
files_2 = ['../output_Mage/output_mutation/mutation_GeneMutation.csv', '../output_Mage/output_mutation/mutation_MultiGeneMutation.csv']
files_3 = ['../output_Warden/output_mutation/mutation_GeneMutation.csv', '../output_Warden/output_mutation/mutation_MultiGeneMutation.csv']
files_4 = ['../output_Warrior/output_mutation/mutation_GeneMutation.csv', '../output_Warrior/output_mutation/mutation_MultiGeneMutation.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ['Single Gene', 'Multi Gene']

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Mutations')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Mutations - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_mutation_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Mutations')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Mutation - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_mutation_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_mutation_variation/mutation_variation_Uniform.csv', '../output_Archer/output_mutation_variation/mutation_variation_NonUniform.csv']
files_2 = ['../output_Mage/output_mutation_variation/mutation_variation_Uniform.csv', '../output_Mage/output_mutation_variation/mutation_variation_NonUniform.csv']
files_3 = ['../output_Warden/output_mutation_variation/mutation_variation_Uniform.csv', '../output_Warden/output_mutation_variation/mutation_variation_NonUniform.csv']
files_4 = ['../output_Warrior/output_mutation_variation/mutation_variation_Uniform.csv', '../output_Warrior/output_mutation_variation/mutation_variation_NonUniform.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ['Uniform','Non Uniform']

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Mutation Variations')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Mutation Variations - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_mutation_variation_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Mutation Variations')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Mutation Variation - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_mutation_variation_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_select1/select1_Boltzmann.csv', '../output_Archer/output_select1/select1_DeterministicTournament.csv',
           '../output_Archer/output_select1/select1_Elite.csv', '../output_Archer/output_select1/select1_ProbabilisticTournament.csv',
           '../output_Archer/output_select1/select1_Ranking.csv', '../output_Archer/output_select1/select1_Roulette.csv',
           '../output_Archer/output_select1/select1_Universal.csv']
files_2 = ['../output_Mage/output_select1/select1_Boltzmann.csv', '../output_Mage/output_select1/select1_DeterministicTournament.csv',
           '../output_Mage/output_select1/select1_Elite.csv', '../output_Mage/output_select1/select1_ProbabilisticTournament.csv',
           '../output_Mage/output_select1/select1_Ranking.csv', '../output_Mage/output_select1/select1_Roulette.csv',
           '../output_Mage/output_select1/select1_Universal.csv']
files_3 = ['../output_Warden/output_select1/select1_Boltzmann.csv', '../output_Warden/output_select1/select1_DeterministicTournament.csv',
           '../output_Warden/output_select1/select1_Elite.csv', '../output_Warden/output_select1/select1_ProbabilisticTournament.csv',
           '../output_Warden/output_select1/select1_Ranking.csv', '../output_Warden/output_select1/select1_Roulette.csv',
           '../output_Warden/output_select1/select1_Universal.csv']
files_4 = ['../output_Warrior/output_select1/select1_Boltzmann.csv', '../output_Warrior/output_select1/select1_DeterministicTournament.csv',
           '../output_Warrior/output_select1/select1_Elite.csv', '../output_Warrior/output_select1/select1_ProbabilisticTournament.csv',
           '../output_Warrior/output_select1/select1_Ranking.csv', '../output_Warrior/output_select1/select1_Roulette.csv',
           '../output_Warrior/output_select1/select1_Universal.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ["Boltzmann","DeterministicTournament","Elite","ProbabilisticTournament","Ranking","Roulette","Universal"]

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('First selection')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per First Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection1_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('First Selection')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per First Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection1_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_select2/select2_Boltzmann.csv', '../output_Archer/output_select2/select2_DeterministicTournament.csv',
           '../output_Archer/output_select2/select2_Elite.csv', '../output_Archer/output_select2/select2_ProbabilisticTournament.csv',
           '../output_Archer/output_select2/select2_Ranking.csv', '../output_Archer/output_select2/select2_Roulette.csv',
           '../output_Archer/output_select2/select2_Universal.csv']
files_2 = ['../output_Mage/output_select2/select2_Boltzmann.csv', '../output_Mage/output_select2/select2_DeterministicTournament.csv',
           '../output_Mage/output_select2/select2_Elite.csv', '../output_Mage/output_select2/select2_ProbabilisticTournament.csv',
           '../output_Mage/output_select2/select2_Ranking.csv', '../output_Mage/output_select2/select2_Roulette.csv',
           '../output_Mage/output_select2/select2_Universal.csv']
files_3 = ['../output_Warden/output_select2/select2_Boltzmann.csv', '../output_Warden/output_select2/select2_DeterministicTournament.csv',
           '../output_Warden/output_select2/select2_Elite.csv', '../output_Warden/output_select2/select2_ProbabilisticTournament.csv',
           '../output_Warden/output_select2/select2_Ranking.csv', '../output_Warden/output_select2/select2_Roulette.csv',
           '../output_Warden/output_select2/select2_Universal.csv']
files_4 = ['../output_Warrior/output_select2/select2_Boltzmann.csv', '../output_Warrior/output_select2/select2_DeterministicTournament.csv',
           '../output_Warrior/output_select2/select2_Elite.csv', '../output_Warrior/output_select2/select2_ProbabilisticTournament.csv',
           '../output_Warrior/output_select2/select2_Ranking.csv', '../output_Warrior/output_select2/select2_Roulette.csv',
           '../output_Warrior/output_select2/select2_Universal.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ["Boltzmann","DeterministicTournament","Elite","ProbabilisticTournament","Ranking","Roulette","Universal"]

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('First selection')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Second Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection2_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Second Selection')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Second Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection2_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_replacement/replacement_Bias.csv', '../output_Archer/output_replacement/replacement_Traditional.csv']
files_2 = ['../output_Mage/output_replacement/replacement_Bias.csv', '../output_Mage/output_replacement/replacement_Traditional.csv']
files_3 = ['../output_Warden/output_replacement/replacement_Bias.csv', '../output_Warden/output_replacement/replacement_Traditional.csv']
files_4 = ['../output_Warrior/output_replacement/replacement_Bias.csv', '../output_Warrior/output_replacement/replacement_Traditional.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ["Bias","Traditional"]

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Replacement Methods')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Replacement Method - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_replacement_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Replacement Methods')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Replacement Method - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_replacement_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_select3/select3_Boltzmann.csv', '../output_Archer/output_select3/select3_DeterministicTournament.csv',
           '../output_Archer/output_select3/select3_Elite.csv', '../output_Archer/output_select3/select3_ProbabilisticTournament.csv',
           '../output_Archer/output_select3/select3_Ranking.csv', '../output_Archer/output_select3/select3_Roulette.csv',
           '../output_Archer/output_select3/select3_Universal.csv']
files_2 = ['../output_Mage/output_select3/select3_Boltzmann.csv', '../output_Mage/output_select3/select3_DeterministicTournament.csv',
           '../output_Mage/output_select3/select3_Elite.csv', '../output_Mage/output_select3/select3_ProbabilisticTournament.csv',
           '../output_Mage/output_select3/select3_Ranking.csv', '../output_Mage/output_select3/select3_Roulette.csv',
           '../output_Mage/output_select3/select3_Universal.csv']
files_3 = ['../output_Warden/output_select3/select3_Boltzmann.csv', '../output_Warden/output_select3/select3_DeterministicTournament.csv',
           '../output_Warden/output_select3/select3_Elite.csv', '../output_Warden/output_select3/select3_ProbabilisticTournament.csv',
           '../output_Warden/output_select3/select3_Ranking.csv', '../output_Warden/output_select3/select3_Roulette.csv',
           '../output_Warden/output_select3/select3_Universal.csv']
files_4 = ['../output_Warrior/output_select3/select3_Boltzmann.csv', '../output_Warrior/output_select3/select3_DeterministicTournament.csv',
           '../output_Warrior/output_select3/select3_Elite.csv', '../output_Warrior/output_select3/select3_ProbabilisticTournament.csv',
           '../output_Warrior/output_select3/select3_Ranking.csv', '../output_Warrior/output_select3/select3_Roulette.csv',
           '../output_Warrior/output_select3/select3_Universal.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ["Boltzmann","DeterministicTournament","Elite","ProbabilisticTournament","Ranking","Roulette","Universal"]

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Third selection')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Third Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection3_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Third Selection')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Third Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection3_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_select4/select4_Boltzmann.csv', '../output_Archer/output_select4/select4_DeterministicTournament.csv',
           '../output_Archer/output_select4/select4_Elite.csv', '../output_Archer/output_select4/select4_ProbabilisticTournament.csv',
           '../output_Archer/output_select4/select4_Ranking.csv', '../output_Archer/output_select4/select4_Roulette.csv',
           '../output_Archer/output_select4/select4_Universal.csv']
files_2 = ['../output_Mage/output_select4/select4_Boltzmann.csv', '../output_Mage/output_select4/select4_DeterministicTournament.csv',
           '../output_Mage/output_select4/select4_Elite.csv', '../output_Mage/output_select4/select4_ProbabilisticTournament.csv',
           '../output_Mage/output_select4/select4_Ranking.csv', '../output_Mage/output_select4/select4_Roulette.csv',
           '../output_Mage/output_select4/select4_Universal.csv']
files_3 = ['../output_Warden/output_select4/select4_Boltzmann.csv', '../output_Warden/output_select4/select4_DeterministicTournament.csv',
           '../output_Warden/output_select4/select4_Elite.csv', '../output_Warden/output_select4/select4_ProbabilisticTournament.csv',
           '../output_Warden/output_select4/select4_Ranking.csv', '../output_Warden/output_select4/select4_Roulette.csv',
           '../output_Warden/output_select4/select4_Universal.csv']
files_4 = ['../output_Warrior/output_select4/select4_Boltzmann.csv', '../output_Warrior/output_select4/select4_DeterministicTournament.csv',
           '../output_Warrior/output_select4/select4_Elite.csv', '../output_Warrior/output_select4/select4_ProbabilisticTournament.csv',
           '../output_Warrior/output_select4/select4_Ranking.csv', '../output_Warrior/output_select4/select4_Roulette.csv',
           '../output_Warrior/output_select4/select4_Universal.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ["Boltzmann","DeterministicTournament","Elite","ProbabilisticTournament","Ranking","Roulette","Universal"]

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Fourth selection')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Fourth Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection4_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Fourth Selection')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Fourth Selection - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_selection4_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_cutoff/cutoff_Content.csv', '../output_Archer/output_cutoff/cutoff_MaxGen.csv', 
           '../output_Archer/output_cutoff/cutoff_Optimum.csv', '../output_Archer/output_cutoff/cutoff_Structure.csv']
files_2 = ['../output_Mage/output_cutoff/cutoff_Content.csv', '../output_Mage/output_cutoff/cutoff_MaxGen.csv',
           '../output_Mage/output_cutoff/cutoff_Optimum.csv', '../output_Mage/output_cutoff/cutoff_Structure.csv']
files_3 = ['../output_Warden/output_cutoff/cutoff_Content.csv', '../output_Warden/output_cutoff/cutoff_MaxGen.csv',
           '../output_Warden/output_cutoff/cutoff_Optimum.csv', '../output_Warden/output_cutoff/cutoff_Structure.csv']
files_4 = ['../output_Warrior/output_cutoff/cutoff_Content.csv', '../output_Warrior/output_cutoff/cutoff_MaxGen.csv',
           '../output_Warrior/output_cutoff/cutoff_Optimum.csv', '../output_Warrior/output_cutoff/cutoff_Structure.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ['Content','MaxGen','Optimum','Structure']

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Cutoffs')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Cutoffs - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_cutoff_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Cutoffs')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Cutoff - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_cutoff_fitness.png')
    plt.savefig(output_path)
    plt.close()

# %%
#AVERAGE GENERATION PER METHOD

import pandas as pd
import matplotlib.pyplot as plt
import os

files_1 = ['../output_Archer/output_cutoff/cutoff_Content.csv', '../output_Archer/output_cutoff/cutoff_MaxGen.csv', 
           '../output_Archer/output_cutoff/cutoff_Optimum.csv', '../output_Archer/output_cutoff/cutoff_Structure.csv']
files_2 = ['../output_Mage/output_cutoff/cutoff_Content.csv', '../output_Mage/output_cutoff/cutoff_MaxGen.csv',
           '../output_Mage/output_cutoff/cutoff_Optimum.csv', '../output_Mage/output_cutoff/cutoff_Structure.csv']
files_3 = ['../output_Warden/output_cutoff/cutoff_Content.csv', '../output_Warden/output_cutoff/cutoff_MaxGen.csv',
           '../output_Warden/output_cutoff/cutoff_Optimum.csv', '../output_Warden/output_cutoff/cutoff_Structure.csv']
files_4 = ['../output_Warrior/output_cutoff/cutoff_Content.csv', '../output_Warrior/output_cutoff/cutoff_MaxGen.csv',
           '../output_Warrior/output_cutoff/cutoff_Optimum.csv', '../output_Warrior/output_cutoff/cutoff_Structure.csv']

# List of file sets and corresponding character names
files = [files_1, files_2, files_3, files_4]
character_names = ['Archer', 'Mage', 'Warden', 'Warrior']
tag_list = ['Content','MaxGen','Optimum','Structure']

# Generate a separate plot for each character
for idx, fileset in enumerate(files):
    generations_list = []
    mean_generations = []
    std_generations = []

    for file in fileset:
        # Read the data and append the final generation value
        data = pd.read_csv(file)
        generations_list.append(data['Generation'].iloc[-1])

    # Calculate mean and standard deviation of generations
    generation_series = pd.Series(generations_list)
    mean_generations = generation_series.mean()
    std_generations = generation_series.std()

    # Create a bar plot for this character
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, generations_list, capsize=10, color='b', alpha=0.7)
    plt.bar_label(barplot, labels=[f'{gen:.2f}' for gen in generations_list], label_type='center')

    # Add labels and title
    plt.xlabel('Cutoffs')
    plt.ylabel('Generation Number')
    plt.title(f'Generations per Cutoffs - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_cutoff_generation_count.png')
    plt.savefig(output_path)
    plt.close()

    # Generate a separate plot for each character based on average Fitness
for idx, fileset in enumerate(files):
    fitness_list = []
    std_fitness_list = []

    for file in fileset:
        # Read the data and calculate the mean fitness
        data = pd.read_csv(file)
        fitness_list.append(data['Fitness'].mean())
        std_fitness_list.append(data['Fitness'].std())

    # Calculate mean and standard deviation of fitness values
    fitness_series = pd.Series(fitness_list)
    mean_fitness = fitness_series.mean()

    # Create a bar plot for this character's fitness
    plt.figure(figsize=(8, 6))
    barplot = plt.bar(tag_list, fitness_list, yerr=std_fitness_list, capsize=10, color='g', alpha=0.7)

    plt.bar_label(barplot, labels=[f'{fitness:.2f}' for fitness in fitness_list], label_type='center')

    # Add labels and title
    plt.xlabel('Cutoffs')
    plt.ylabel('Average Fitness')
    plt.title(f'Average Fitness per Cutoff - {character_names[idx]}')
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Display the plot
    output_path = os.path.join("images", f'{character_names[idx]}_cutoff_fitness.png')
    plt.savefig(output_path)
    plt.close()
